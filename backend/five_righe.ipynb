# %%
import pandas as pd
df = pd.read_csv("Gesamtdatensatz.csv")
df.head()
# Out:
#               timestamp  location_id           location_name     ltr_label  \
# 0  2021-09-28T22:00:00Z          329  Bahnhofstrasse (Mitte)  Hauptbahnhof
# 1  2021-09-28T22:00:00Z          331   Bahnhofstrasse (Nord)   Bürkliplatz
# 2  2021-09-28T22:00:00Z          330    Bahnhofstrasse (Süd)   Bürkliplatz
# 3  2021-09-28T22:00:00Z          670        Lintheschergasse  Hauptbahnhof
# 4  2021-09-28T23:00:00Z          329  Bahnhofstrasse (Mitte)  Hauptbahnhof
#
#       rtl_label weather_condition  temperature  pedestrians_count  unverified  \
# 0   Bürkliplatz            cloudy        13.51                151       False
# 1  Hauptbahnhof            cloudy        13.51                118       False
# 2  Hauptbahnhof            cloudy        13.51                203       False
# 3  Uraniastraße            cloudy        13.51                  0       False
# 4   Bürkliplatz            cloudy        13.46                 19       False
#
# ...
